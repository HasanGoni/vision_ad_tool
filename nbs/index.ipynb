# %%
#| hide
from be_vision_ad_tools.core import *

# %% [markdown]
# # be-vision-ad-tools
#
# > Anomaly detection tool for images

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install be_vision_ad_tools in Development mode

# %% [markdown]
# ```sh
# # make sure be_vision_ad_tools package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to be_vision_ad_tools
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/tools/be-vision-ad-tools.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c tools be_vision_ad_tools
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install be_vision_ad_tools
# ```
#
#
# [repo]: https://github.com/tools/be-vision-ad-tools
# [docs]: https://tools.github.io/be-vision-ad-tools/
# [pypi]: https://pypi.org/project/be-vision-ad-tools/
# [conda]: https://anaconda.org/tools/be-vision-ad-tools

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/tools/be-vision-ad-tools
# [docs]: https://tools.github.io/be-vision-ad-tools/
# [pypi]: https://pypi.org/project/be-vision-ad-tools/
# [conda]: https://anaconda.org/tools/be-vision-ad-tools

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
